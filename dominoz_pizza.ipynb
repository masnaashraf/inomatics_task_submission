# %% [markdown]
# <a href="https://colab.research.google.com/github/masnaashraf/inomatics_task_submission/blob/main/dominoz_pizza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Loading Dataset

df = pd.read_csv("diminos_data.csv")

# %%
df.head()
# Out:
#    order_id      order_placed_at          order_delivered_at
# 0   1523111  2023-03-01 00:00:59  2023-03-01 00:18:07.443132
# 1   1523112  2023-03-01 00:03:59  2023-03-01 00:19:34.925241
# 2   1523113  2023-03-01 00:07:22  2023-03-01 00:22:28.291385
# 3   1523114  2023-03-01 00:07:47  2023-03-01 00:46:19.019399
# 4   1523115  2023-03-01 00:09:03  2023-03-01 00:25:13.619056

# %%
df.shape
# Out:
# (15000, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            15000 non-null  int64
#  1   order_placed_at     15000 non-null  object
#  2   order_delivered_at  15000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 351.7+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'order_placed_at', 'order_delivered_at'], dtype='object')

# %%
df['order_placed_at'] = pd.to_datetime(df['order_placed_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            15000 non-null  int64
#  1   order_placed_at     15000 non-null  datetime64[ns]
#  2   order_delivered_at  15000 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 351.7+ KB

# %%
df.head()
# Out:
#    order_id     order_placed_at          order_delivered_at
# 0   1523111 2023-03-01 00:00:59  2023-03-01 00:18:07.443132
# 1   1523112 2023-03-01 00:03:59  2023-03-01 00:19:34.925241
# 2   1523113 2023-03-01 00:07:22  2023-03-01 00:22:28.291385
# 3   1523114 2023-03-01 00:07:47  2023-03-01 00:46:19.019399
# 4   1523115 2023-03-01 00:09:03  2023-03-01 00:25:13.619056

# %%
df['order_delivered_at'] = pd.to_datetime(df['order_delivered_at'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            15000 non-null  int64
#  1   order_placed_at     15000 non-null  datetime64[ns]
#  2   order_delivered_at  15000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1)
# memory usage: 351.7 KB

# %%
df.head()
# Out:
#    order_id     order_placed_at         order_delivered_at
# 0   1523111 2023-03-01 00:00:59 2023-03-01 00:18:07.443132
# 1   1523112 2023-03-01 00:03:59 2023-03-01 00:19:34.925241
# 2   1523113 2023-03-01 00:07:22 2023-03-01 00:22:28.291385
# 3   1523114 2023-03-01 00:07:47 2023-03-01 00:46:19.019399
# 4   1523115 2023-03-01 00:09:03 2023-03-01 00:25:13.619056

# %%
df['order_placed_day'] = df['order_placed_at'].dt.day
df['order_placed_weekday'] = df['order_placed_at'].dt.weekday
df['order_placed_hour'] = df['order_placed_at'].dt.hour
df['order_placed_minute'] = df['order_placed_at'].dt.minute
df['order_placed_second'] = df['order_placed_at'].dt.second

# %%
df.head()
# Out:
#    order_id     order_placed_at         order_delivered_at  order_placed_day  \
# 0   1523111 2023-03-01 00:00:59 2023-03-01 00:18:07.443132                 1
# 1   1523112 2023-03-01 00:03:59 2023-03-01 00:19:34.925241                 1
# 2   1523113 2023-03-01 00:07:22 2023-03-01 00:22:28.291385                 1
# 3   1523114 2023-03-01 00:07:47 2023-03-01 00:46:19.019399                 1
# 4   1523115 2023-03-01 00:09:03 2023-03-01 00:25:13.619056                 1
#
#    order_placed_weekday  order_placed_hour  order_placed_minute  \
# 0                     2                  0                    0
# 1                     2                  0                    3
# 2                     2                  0                    7
# 3                     2                  0                    7
# 4                     2                  0                    9
#
#    order_placed_second
# 0                   59
# 1                   59
# 2                   22
# ...

# %%
print("Printing unique values of each column")
for i in df.columns[:]:
  print("*"*70)
  print("number of unique values of ",i," column :",df[i].nunique())
  print("unique values:")
  print(df[i].unique())
# Out:
# Printing unique values of each column
# **********************************************************************
# number of unique values of  order_id  column : 15000
# unique values:
# [1523111 1523112 1523113 ... 1538108 1538109 1538110]
# **********************************************************************
# number of unique values of  order_placed_at  column : 14953
# unique values:
# ['2023-03-01T00:00:59.000000000' '2023-03-01T00:03:59.000000000'
#  '2023-03-01T00:07:22.000000000' ... '2023-03-27T23:50:16.000000000'
#  '2023-03-27T23:52:44.000000000' '2023-03-27T23:58:20.000000000']
# **********************************************************************
# number of unique values of  order_delivered_at  column : 15000
# unique values:
# ['2023-03-01T00:18:07.443132000' '2023-03-01T00:19:34.925241000'
#  '2023-03-01T00:22:28.291385000' ... '2023-03-28T00:05:40.676238000'
#  '2023-03-28T00:08:41.810358000' '2023-03-28T00:13:42.499311000']
# ...

# %%
df['order_delivered_day'] = df['order_delivered_at'].dt.day
df['order_delivered_weekday'] = df['order_delivered_at'].dt.weekday
df['order_delivered_hour'] = df['order_delivered_at'].dt.hour
df['order_delivered_minute'] = df['order_delivered_at'].dt.minute
df['order_delivered_second'] = df['order_delivered_at'].dt.second

# %%
print("Printing unique values of each column")
for i in df.columns[:]:
  print("*"*70)
  print("number of unique values of ",i," column :",df[i].nunique())
  print("unique values:")
  print(df[i].unique())
# Out:
# Printing unique values of each column
# **********************************************************************
# number of unique values of  order_id  column : 15000
# unique values:
# [1523111 1523112 1523113 ... 1538108 1538109 1538110]
# **********************************************************************
# number of unique values of  order_placed_at  column : 14953
# unique values:
# ['2023-03-01T00:00:59.000000000' '2023-03-01T00:03:59.000000000'
#  '2023-03-01T00:07:22.000000000' ... '2023-03-27T23:50:16.000000000'
#  '2023-03-27T23:52:44.000000000' '2023-03-27T23:58:20.000000000']
# **********************************************************************
# number of unique values of  order_delivered_at  column : 15000
# unique values:
# ['2023-03-01T00:18:07.443132000' '2023-03-01T00:19:34.925241000'
#  '2023-03-01T00:22:28.291385000' ... '2023-03-28T00:05:40.676238000'
#  '2023-03-28T00:08:41.810358000' '2023-03-28T00:13:42.499311000']
# ...

# %%
df.head()
# Out:
#    order_id     order_placed_at         order_delivered_at  order_placed_day  \
# 0   1523111 2023-03-01 00:00:59 2023-03-01 00:18:07.443132                 1
# 1   1523112 2023-03-01 00:03:59 2023-03-01 00:19:34.925241                 1
# 2   1523113 2023-03-01 00:07:22 2023-03-01 00:22:28.291385                 1
# 3   1523114 2023-03-01 00:07:47 2023-03-01 00:46:19.019399                 1
# 4   1523115 2023-03-01 00:09:03 2023-03-01 00:25:13.619056                 1
#
#    order_placed_weekday  order_placed_hour  order_placed_minute  \
# 0                     2                  0                    0
# 1                     2                  0                    3
# 2                     2                  0                    7
# 3                     2                  0                    7
# 4                     2                  0                    9
#
#    order_placed_second  order_delivered_day  order_delivered_weekday  \
# ...

# %%
df.shape
# Out:
# (15000, 13)

# %%
df['time_taken']=df['order_delivered_at']-df['order_placed_at']

# %%
df['time_taken']
# Out:
# 0       0 days 00:17:08.443132
# 1       0 days 00:15:35.925241
# 2       0 days 00:15:06.291385
# 3       0 days 00:38:32.019399
# 4       0 days 00:16:10.619056
#                  ...
# 14995   0 days 00:15:32.409378
# 14996   0 days 00:16:44.672912
# 14997   0 days 00:15:24.676238
# 14998   0 days 00:15:57.810358
# 14999   0 days 00:15:22.499311
# Name: time_taken, Length: 15000, dtype: timedelta64[ns]

# %%
df['time_taken_seconds'] = df['time_taken'].dt.total_seconds().astype(int)
df['time_taken_minutes'] = df['time_taken'].dt.total_seconds() // 60

# %%
df.head()
# Out:
#    order_id     order_placed_at         order_delivered_at  order_placed_day  \
# 0   1523111 2023-03-01 00:00:59 2023-03-01 00:18:07.443132                 1
# 1   1523112 2023-03-01 00:03:59 2023-03-01 00:19:34.925241                 1
# 2   1523113 2023-03-01 00:07:22 2023-03-01 00:22:28.291385                 1
# 3   1523114 2023-03-01 00:07:47 2023-03-01 00:46:19.019399                 1
# 4   1523115 2023-03-01 00:09:03 2023-03-01 00:25:13.619056                 1
#
#    order_placed_weekday  order_placed_hour  order_placed_minute  \
# 0                     2                  0                    0
# 1                     2                  0                    3
# 2                     2                  0                    7
# 3                     2                  0                    7
# 4                     2                  0                    9
#
#    order_placed_second  order_delivered_day  order_delivered_weekday  \
# ...

# %%
df['duration_lapse'] = df.apply(lambda x: '{:02d}:{:02d}'.format(int(x['time_taken_minutes']), int(x['time_taken_seconds']) % 60), axis=1)

# %%
df
# Out:
#        order_id     order_placed_at         order_delivered_at  \
# 0       1523111 2023-03-01 00:00:59 2023-03-01 00:18:07.443132
# 1       1523112 2023-03-01 00:03:59 2023-03-01 00:19:34.925241
# 2       1523113 2023-03-01 00:07:22 2023-03-01 00:22:28.291385
# 3       1523114 2023-03-01 00:07:47 2023-03-01 00:46:19.019399
# 4       1523115 2023-03-01 00:09:03 2023-03-01 00:25:13.619056
# ...         ...                 ...                        ...
# 14995   1538106 2023-03-27 23:37:05 2023-03-27 23:52:37.409378
# 14996   1538107 2023-03-27 23:47:38 2023-03-28 00:04:22.672912
# 14997   1538108 2023-03-27 23:50:16 2023-03-28 00:05:40.676238
# 14998   1538109 2023-03-27 23:52:44 2023-03-28 00:08:41.810358
# 14999   1538110 2023-03-27 23:58:20 2023-03-28 00:13:42.499311
#
#        order_placed_day  order_placed_weekday  order_placed_hour  \
# 0                     1                     2                  0
# 1                     1                     2                  0
# ...

# %%
q90 = df['time_taken'].quantile(0.9)
q90
# Out:
# Timedelta('0 days 00:21:09.414273300')

# %%
q50 = df['time_taken'].quantile(0.5)
q50
# Out:
# Timedelta('0 days 00:15:47.879164')

# %%
q60 = df['time_taken'].quantile(0.6)
q60
# Out:
# Timedelta('0 days 00:16:09.680534')

# %%
q70 = df['time_taken'].quantile(0.7)
q70
# Out:
# Timedelta('0 days 00:16:48.125792699')

# %%
q80 = df['time_taken'].quantile(0.8)
q80
# Out:
# Timedelta('0 days 00:17:57.573245800')

# %%
max_duration = df['time_taken'].max()
max_duration
# Out:
# Timedelta('5 days 01:39:49.882496')

# %%
min_duration = df['time_taken'].min()
min_duration
# Out:
# Timedelta('0 days 00:15:00.000620')

# %%
# compute the difference between the 90th quartile and the maximum duration
diff = max_duration - q90
diff
# Out:
# Timedelta('5 days 01:18:40.468222700')

# %%
df[df['time_taken']=='5 days 01:39:49.882496']
# Out:
#       order_id     order_placed_at         order_delivered_at  \
# 5499   1528610 2023-03-10 17:06:22 2023-03-15 18:46:11.882496
#
#       order_placed_day  order_placed_weekday  order_placed_hour  \
# 5499                10                     4                 17
#
#       order_placed_minute  order_placed_second  order_delivered_day  \
# 5499                    6                   22                   15
#
#       order_delivered_weekday  order_delivered_hour  order_delivered_minute  \
# 5499                        2                    18                      46
#
#       order_delivered_second             time_taken  time_taken_seconds  \
# 5499                      11 5 days 01:39:49.882496              437989
#
#       time_taken_minutes duration_lapse
# 5499              7299.0        7299:49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_id                 15000 non-null  int64
#  1   order_placed_at          15000 non-null  datetime64[ns]
#  2   order_delivered_at       15000 non-null  datetime64[ns]
#  3   order_placed_day         15000 non-null  int64
#  4   order_placed_weekday     15000 non-null  int64
#  5   order_placed_hour        15000 non-null  int64
#  6   order_placed_minute      15000 non-null  int64
#  7   order_placed_second      15000 non-null  int64
#  8   order_delivered_day      15000 non-null  int64
#  9   order_delivered_weekday  15000 non-null  int64
#  10  order_delivered_hour     15000 non-null  int64
#  11  order_delivered_minute   15000 non-null  int64
#  12  order_delivered_second   15000 non-null  int64
# ...

# %%
df_extreme=df[(df['order_delivered_day'] != df['order_placed_day']) & (df['time_taken_minutes'] > 30.0)]

# %%
df_extreme
# Out:
#        order_id     order_placed_at         order_delivered_at  \
# 460     1523571 2023-03-01 20:29:53 2023-03-02 01:17:46.815054
# 1122    1524233 2023-03-02 23:20:32 2023-03-03 00:01:24.247254
# 1361    1524472 2023-03-03 10:04:13 2023-03-04 03:51:02.368715
# 1660    1524771 2023-03-03 23:31:59 2023-03-04 00:07:45.032076
# 1662    1524773 2023-03-03 23:35:15 2023-03-04 01:09:29.920723
# 2201    1525312 2023-03-04 22:25:20 2023-03-05 00:34:36.188065
# 2718    1525829 2023-03-05 21:20:26 2023-03-06 00:23:44.616863
# 2741    1525852 2023-03-05 22:16:39 2023-03-06 07:23:17.239715
# 2747    1525858 2023-03-05 22:22:11 2023-03-06 02:08:13.724429
# 2764    1525875 2023-03-05 23:02:39 2023-03-06 00:00:26.691390
# 2775    1525886 2023-03-05 23:25:44 2023-03-06 03:11:28.158506
# 2776    1525887 2023-03-05 23:29:49 2023-03-06 00:10:07.775102
# 2784    1525895 2023-03-05 23:43:26 2023-03-06 00:18:27.193791
# 3356    1526467 2023-03-06 23:35:57 2023-03-07 01:29:32.115694
# ...

# %%
df_extreme.shape
# Out:
# (39, 17)

# %%
#out of 15000 orders 39 were shown as not serve on time so this can be some outliers can consider of dropping this

# %%
df = df.drop(df_extreme.index)

# %%
df.shape
# Out:
# (14961, 17)

# %%
df_extreme_minutes=df[df['time_taken_minutes'] > 30.0]

# %%
df_extreme_minutes.shape
# Out:
# (518, 17)

# %%
#After removing outlier there are 518 records where the delivery time is more than 30 minutes .so 96.54 percent of time they are delivering befor 30 minutes

# %%
q91 = df['time_taken'].quantile(0.91)
q91
# Out:
# Timedelta('0 days 00:21:35.357238200')

# %%
q92 = df['time_taken'].quantile(0.92)
q92
# Out:
# Timedelta('0 days 00:22:23.483059800')

# %%
q93 = df['time_taken'].quantile(0.93)
q93
# Out:
# Timedelta('0 days 00:23:25.081607800')

# %%
q94 = df['time_taken'].quantile(0.94)
q94
# Out:
# Timedelta('0 days 00:24:42.465182399')

# %%
q95 = df['time_taken'].quantile(0.95)
q95
# Out:
# Timedelta('0 days 00:26:35.395212')

# %%
q96 = df['time_taken'].quantile(0.96)
q96
# Out:
# Timedelta('0 days 00:29:08.711820600')

# %%
q97 = df['time_taken'].quantile(0.97)
q97
# Out:
# Timedelta('0 days 00:32:48.678195200')

# %% [markdown]
# till 95th qurtile ontime deliver is being done
# in 96th quartile time taken is 30:07.277
# and on 97 th quartile time taken is 33:56.16

# %% [markdown]
# * till 96th qurtile ontime delivery is being done
# * on 97 th quartile time taken is 32:48.6781

# %% [markdown]
# There is one day in the list where delvery is shown after 5 days gap
#
# 2023-03-15 18:46:11.882496	with gap of 5 days 01:39:49.882496

# %%
df.columns
# Out:
# Index(['order_id', 'order_placed_at', 'order_delivered_at', 'order_placed_day',
#        'order_placed_hour', 'order_placed_minute', 'order_placed_second',
#        'order_delivered_day', 'order_delivered_hour', 'order_delivered_minute',
#        'order_delivered_second', 'time_taken', 'time_taken_seconds',
#        'time_taken_minutes', 'duration_lapse'],
#       dtype='object')

# %%
df['order_placed_day'].value_counts(ascending =False)
# Out:
# 20    597
# 22    589
# 2     587
# 10    586
# 23    581
# 6     580
# 12    580
# 8     577
# 7     570
# 4     566
# 24    565
# 9     563
# 18    559
# 27    551
# 1     549
# 25    546
# 5     544
# 16    543
# 15    539
# 17    537
# 11    534
# 3     531
# 26    530
# 13    526
# 19    522
# 21    519
# 14    490
# Name: order_placed_day, dtype: int64

# %% [markdown]
# order is placed more on 20th March 2023 -597 and
# order placed least at 14th marth 2023 - 492

# %%
order_20=df[df['order_placed_day']==20]

# %%
order_20['order_placed_hour'].value_counts()
# Out:
# 16    34
# 23    33
# 5     30
# 12    30
# 18    29
# 14    27
# 7     27
# 6     26
# 22    26
# 9     26
# 19    26
# 17    25
# 4     25
# 3     24
# 11    24
# 8     24
# 13    23
# 1     23
# 10    23
# 21    20
# 0     19
# 15    18
# 20    18
# 2     17
# Name: order_placed_hour, dtype: int64

# %%
order_20['order_placed_hour'].plot(kind='hist',bins=24)
# Out:
# <Axes: ylabel='Frequency'>

# %%
order_14=df[df['order_placed_day']==14]

# %%
order_14['order_placed_hour'].value_counts(ascending =False)
# Out:
# 5     26
# 19    26
# 12    25
# 17    25
# 2     24
# 21    24
# 9     23
# 22    23
# 1     23
# 23    23
# 6     23
# 13    21
# 16    20
# 18    20
# 20    20
# 11    19
# 15    19
# 4     17
# 7     16
# 0     16
# 14    15
# 3     15
# 10    14
# 8     13
# Name: order_placed_hour, dtype: int64

# %%
order_14['order_placed_hour'].plot(kind='hist',bins=24)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['order_placed_weekday'].value_counts(ascending =False)
# Out:
# 3    2274
# 2    2254
# 0    2254
# 4    2219
# 5    2205
# 6    2176
# 1    1579
# Name: order_placed_weekday, dtype: int64

# %%
#Since Monday is 0 3 is Thursday 
#Most number of oders where on Thursday with no of orders 2274 and least on Tuesday with no of orders 1579

# %%
order_Thursday=df[df['order_placed_weekday']==3]

# %%
order_Thursday['order_placed_hour'].value_counts(ascending =False)
# Out:
# 6     119
# 11    119
# 21    115
# 18    108
# 23    103
# 19    100
# 13    100
# 9     100
# 14     99
# 5      97
# 10     97
# 3      97
# 7      93
# 16     93
# 20     91
# 8      89
# 4      88
# 22     88
# 17     87
# 0      85
# 12     81
# 2      80
# 15     73
# 1      72
# Name: order_placed_hour, dtype: int64

# %%
order_Tuesday=df[df['order_placed_weekday']==1]

# %%
order_Tuesday['order_placed_hour'].value_counts(ascending =False)
# Out:
# 6     79
# 21    76
# 5     74
# 19    74
# 18    72
# 17    71
# 15    70
# 2     70
# 9     70
# 23    69
# 10    68
# 13    68
# 22    67
# 11    67
# 1     64
# 12    62
# 4     61
# 8     60
# 16    59
# 14    59
# 7     58
# 20    57
# 3     53
# 0     51
# Name: order_placed_hour, dtype: int64

# %% [markdown]
# Insights:
#
#
# * before outlier removal  till 95th quartile ontime deliver is being done in 96th quartile time taken is 30:07.277 and on 97 th quartile time taken is 33:56.16
#
# *   There is one day in the list where delvery is shown after 5 days gap
# 2023-03-15 18:46:11.882496 with gap of 5 days 01:39:49.882496.so it shows some otliers are present.So outlier removal is done
#
# out of 15000 orders 39 were shown as not serve on time so this can be some outliers can consider of dropping this
#
# After removing outlier there are 518 records where the delivery time is more than 30 minutes and delivery day is not on the same day.so 96.54 percent of time they are delivering befor 30 minutes
#
# after outlier removal till 96th quartile ontime delivery is being done on 97 th quartile time taken is 32:48.6781
#
#
# *   order is placed more on 20th March 2023 -597 orders and maximum order was done during the 16th hour on that day with number of orders 34 and minimum order was done on 2nd hour with 17 orders
#
# *  and order placed least at 14th march 2023 - 490 order.maximum order was done during the 5th hour on that day with number of orders 26 and minimum order was done on 8th hour with 13 orders
#
# * #out of 15000 orders 39 were shown as not serve on time so this can be some outliers can consider of dropping this
#
# *   #After removing outlier there are 518 records where the delivery time is more than 30 minutes .so 96.54 percent of time they are delivering befor 30 minutes
#
#
# *   after outlier removal till 96th quartile ontime delivery is being done
# on 97 th quartile time taken is 32:48.6781
#
# *  Most number of orders where on Thursday with no of orders 2274 and Most orders place on 6th hour with 119 orders and least number of orders on 1at hour with 72 orders
#
#
# *   least on Tuesday with no of orders 1579.Most orders place on 6th hour with 79 orders and least number of orders on 1at hour with 51 orders
